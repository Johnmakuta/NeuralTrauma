# %%
# Main Setup

# imports
import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import numpy as np
import itertools

# dataloader arguments
batch_size = 128
data_path='/tmp/data/mnist'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
            transforms.Resize((28, 28)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Network Architecture
num_inputs = 28*28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.70

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Leaky(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Leaky(beta=beta)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_leaky()
        mem2 = self.lif2.init_leaky()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
for i in range(10):

    # Load the network onto CUDA if available
    net = Net().to(device)

    # pass data into the network, sum the spikes over time
    # and compare the neuron with the highest number of spikes
    # with the target

    def print_batch_accuracy(data, targets, train=False):
        output, _ = net(data.view(batch_size, -1))
        _, idx = output.sum(dim=0).max(1)
        acc = np.mean((targets == idx).detach().cpu().numpy())

        if train:
            print(f"Train set accuracy for a single minibatch: {acc*100:.2f}%")
        else:
            print(f"Test set accuracy for a single minibatch: {acc*100:.2f}%")

    def train_printer(
        data, targets, epoch,
        counter, iter_counter,
            loss_hist, test_loss_hist, test_data, test_targets):
        print(f"Epoch {epoch}, Iteration {iter_counter}")
        print(f"Train Set Loss: {loss_hist[counter]:.2f}")
        print(f"Test Set Loss: {test_loss_hist[counter]:.2f}")
        print_batch_accuracy(data, targets, train=True)
        print_batch_accuracy(test_data, test_targets, train=False)
        print("\n")

    loss = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=5e-4, betas=(0.9, 0.999))

    data, targets = next(iter(train_loader))
    data = data.to(device)
    targets = targets.to(device)

    spk_rec, mem_rec = net(data.view(batch_size, -1))
    # print(mem_rec.size())

    # initialize the total loss value
    loss_val = torch.zeros((1), dtype=dtype, device=device)

    # sum loss at every step
    for step in range(num_steps):
        loss_val += loss(mem_rec[step], targets)

    # print(f"Training loss: {loss_val.item():.3f}")
    # print_batch_accuracy(data, targets, train=True)

    # clear previously stored gradients
    optimizer.zero_grad()

    # calculate the gradients
    loss_val.backward()

    # weight update
    optimizer.step()

    # calculate new network outputs using the same data
    spk_rec, mem_rec = net(data.view(batch_size, -1))

    # initialize the total loss value
    loss_val = torch.zeros((1), dtype=dtype, device=device)

    # sum loss at every step
    for step in range(num_steps):
        loss_val += loss(mem_rec[step], targets)

    # print(f"Training loss: {loss_val.item():.3f}")
    # print_batch_accuracy(data, targets, train=True)

    # Training Loop 
    num_epochs = 1
    loss_hist = []
    test_loss_hist = []
    counter = 0

    # Outer training loop
    for epoch in range(num_epochs):
        iter_counter = 0
        train_batch = iter(train_loader)

        # Minibatch training loop
        for data, targets in train_batch:
            data = data.to(device)
            targets = targets.to(device)

            # forward pass
            net.train()
            spk_rec, mem_rec = net(data.view(batch_size, -1))

            # initialize the loss & sum over time
            loss_val = torch.zeros((1), dtype=dtype, device=device)
            for step in range(num_steps):
                loss_val += loss(mem_rec[step], targets)

            # Gradient calculation + weight update
            optimizer.zero_grad()
            loss_val.backward()
            optimizer.step()

            # Store loss history for future plotting
            loss_hist.append(loss_val.item())

            # Test set
            with torch.no_grad():
                net.eval()
                test_data, test_targets = next(iter(test_loader))
                test_data = test_data.to(device)
                test_targets = test_targets.to(device)

                # Test set forward pass
                test_spk, test_mem = net(test_data.view(batch_size, -1))

                # Test set loss
                test_loss = torch.zeros((1), dtype=dtype, device=device)
                for step in range(num_steps):
                    test_loss += loss(test_mem[step], test_targets)
                test_loss_hist.append(test_loss.item())

                # Print train/test loss/accuracy
                if counter % 50 == 0:
                    train_printer(
                        data, targets, epoch,
                        counter, iter_counter,
                        loss_hist, test_loss_hist,
                        test_data, test_targets)
                counter += 1
                iter_counter +=1

    # Test Accuracy

    total = 0
    correct = 0

    # drop_last switched to False to keep all samples
    test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

    with torch.no_grad():
        net.eval()
        for data, targets in test_loader:
            data = data.to(device)
            targets = targets.to(device)
            
            # forward pass
            test_spk, _ = net(data.view(data.size(0), -1))

            # calculate total accuracy
            _, predicted = test_spk.sum(dim=0).max(1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    print(f"Total correctly classified test set images: {correct}/{total}")
    print(f"Test Set Accuracy: {100 * correct / total:.2f}%")



    filename = 'ref_snn_leaky_' + str(i) + '.pth'
    torch.save(net.state_dict(), filename)
    print(f"Finished Net#{i+1}")
# Out:
# Epoch 0, Iteration 0
# Train Set Loss: 55.91
# Test Set Loss: 54.42
# Train set accuracy for a single minibatch: 8.59%
# Test set accuracy for a single minibatch: 9.38%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 17.21
# Test Set Loss: 9.67
# Train set accuracy for a single minibatch: 80.47%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 7.87
# Test Set Loss: 9.41
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 88.28%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 6.83
# Test Set Loss: 6.23
# Train set accuracy for a single minibatch: 88.28%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 6.29
# Test Set Loss: 8.87
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 6.29
# Test Set Loss: 5.36
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 8.54
# Test Set Loss: 7.02
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 88.28%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 6.37
# Test Set Loss: 7.73
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 3.57
# Test Set Loss: 4.02
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 95.31%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 4.74
# Test Set Loss: 5.22
# Train set accuracy for a single minibatch: 94.53%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Total correctly classified test set images: 9313/10000
# Test Set Accuracy: 93.13%
# Finished Net#1
# Epoch 0, Iteration 0
# Train Set Loss: 56.12
# Test Set Loss: 54.80
# Train set accuracy for a single minibatch: 8.59%
# Test set accuracy for a single minibatch: 12.50%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 10.68
# Test Set Loss: 10.72
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 84.38%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 10.42
# Test Set Loss: 6.96
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 8.91
# Test Set Loss: 9.30
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 6.16
# Test Set Loss: 6.55
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 7.94
# Test Set Loss: 5.84
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 5.37
# Test Set Loss: 5.20
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 4.23
# Test Set Loss: 6.54
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 3.48
# Test Set Loss: 3.87
# Train set accuracy for a single minibatch: 94.53%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 3.25
# Test Set Loss: 3.65
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Total correctly classified test set images: 9290/10000
# Test Set Accuracy: 92.90%
# Finished Net#2
# Epoch 0, Iteration 0
# Train Set Loss: 56.60
# Test Set Loss: 54.94
# Train set accuracy for a single minibatch: 10.94%
# Test set accuracy for a single minibatch: 11.72%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 10.22
# Test Set Loss: 10.34
# Train set accuracy for a single minibatch: 85.16%
# Test set accuracy for a single minibatch: 84.38%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 9.81
# Test Set Loss: 9.41
# Train set accuracy for a single minibatch: 88.28%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 8.09
# Test Set Loss: 8.19
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 8.86
# Test Set Loss: 6.99
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 4.50
# Test Set Loss: 4.93
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 7.93
# Test Set Loss: 4.60
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 5.69
# Test Set Loss: 4.83
# Train set accuracy for a single minibatch: 88.28%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 7.32
# Test Set Loss: 4.05
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 5.48
# Test Set Loss: 3.86
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 95.31%
#
#
# Total correctly classified test set images: 9271/10000
# Test Set Accuracy: 92.71%
# Finished Net#3
# Epoch 0, Iteration 0
# Train Set Loss: 56.01
# Test Set Loss: 54.90
# Train set accuracy for a single minibatch: 8.59%
# Test set accuracy for a single minibatch: 7.03%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 9.84
# Test Set Loss: 9.85
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 86.72%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 14.14
# Test Set Loss: 9.81
# Train set accuracy for a single minibatch: 78.91%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 8.71
# Test Set Loss: 5.55
# Train set accuracy for a single minibatch: 86.72%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 11.12
# Test Set Loss: 8.86
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 86.72%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 12.48
# Test Set Loss: 5.97
# Train set accuracy for a single minibatch: 85.94%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 6.35
# Test Set Loss: 5.07
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 6.56
# Test Set Loss: 5.50
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 4.85
# Test Set Loss: 3.33
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 4.31
# Test Set Loss: 2.65
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Total correctly classified test set images: 9150/10000
# Test Set Accuracy: 91.50%
# Finished Net#4
# Epoch 0, Iteration 0
# Train Set Loss: 56.11
# Test Set Loss: 54.18
# Train set accuracy for a single minibatch: 10.16%
# Test set accuracy for a single minibatch: 9.38%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 12.46
# Test Set Loss: 11.40
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 8.24
# Test Set Loss: 12.66
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 7.23
# Test Set Loss: 8.27
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 7.52
# Test Set Loss: 6.23
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 94.53%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 13.32
# Test Set Loss: 6.25
# Train set accuracy for a single minibatch: 85.94%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 4.18
# Test Set Loss: 6.72
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 4.97
# Test Set Loss: 4.67
# Train set accuracy for a single minibatch: 96.88%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 5.28
# Test Set Loss: 3.75
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 94.53%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 3.78
# Test Set Loss: 5.01
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Total correctly classified test set images: 9380/10000
# Test Set Accuracy: 93.80%
# Finished Net#5
# Epoch 0, Iteration 0
# Train Set Loss: 56.21
# Test Set Loss: 53.65
# Train set accuracy for a single minibatch: 11.72%
# Test set accuracy for a single minibatch: 15.62%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 10.14
# Test Set Loss: 9.22
# Train set accuracy for a single minibatch: 86.72%
# Test set accuracy for a single minibatch: 86.72%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 10.87
# Test Set Loss: 10.83
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 9.48
# Test Set Loss: 9.92
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 13.55
# Test Set Loss: 8.78
# Train set accuracy for a single minibatch: 85.16%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 4.93
# Test Set Loss: 3.23
# Train set accuracy for a single minibatch: 97.66%
# Test set accuracy for a single minibatch: 96.88%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 6.19
# Test Set Loss: 5.17
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 96.88%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 5.59
# Test Set Loss: 6.52
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 88.28%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 9.07
# Test Set Loss: 4.32
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 96.09%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 6.56
# Test Set Loss: 4.99
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Total correctly classified test set images: 9392/10000
# Test Set Accuracy: 93.92%
# Finished Net#6
# Epoch 0, Iteration 0
# Train Set Loss: 55.97
# Test Set Loss: 53.77
# Train set accuracy for a single minibatch: 5.47%
# Test set accuracy for a single minibatch: 16.41%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 12.90
# Test Set Loss: 9.64
# Train set accuracy for a single minibatch: 86.72%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 9.48
# Test Set Loss: 10.90
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 12.53
# Test Set Loss: 6.25
# Train set accuracy for a single minibatch: 84.38%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 7.33
# Test Set Loss: 6.32
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 8.24
# Test Set Loss: 7.57
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 6.81
# Test Set Loss: 5.11
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 4.03
# Test Set Loss: 4.76
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 5.37
# Test Set Loss: 2.90
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 94.53%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 5.53
# Test Set Loss: 4.23
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Total correctly classified test set images: 9303/10000
# Test Set Accuracy: 93.03%
# Finished Net#7
# Epoch 0, Iteration 0
# Train Set Loss: 55.68
# Test Set Loss: 53.87
# Train set accuracy for a single minibatch: 7.81%
# Test set accuracy for a single minibatch: 13.28%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 8.56
# Test Set Loss: 15.85
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 83.59%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 11.18
# Test Set Loss: 12.16
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 8.94
# Test Set Loss: 7.89
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 8.64
# Test Set Loss: 4.16
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 94.53%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 5.05
# Test Set Loss: 5.50
# Train set accuracy for a single minibatch: 94.53%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 5.22
# Test Set Loss: 3.21
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 96.09%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 5.74
# Test Set Loss: 7.11
# Train set accuracy for a single minibatch: 90.62%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 2.98
# Test Set Loss: 4.38
# Train set accuracy for a single minibatch: 95.31%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 3.25
# Test Set Loss: 3.60
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 93.75%
#
#
# Total correctly classified test set images: 9272/10000
# Test Set Accuracy: 92.72%
# Finished Net#8
# Epoch 0, Iteration 0
# Train Set Loss: 55.74
# Test Set Loss: 53.75
# Train set accuracy for a single minibatch: 6.25%
# Test set accuracy for a single minibatch: 11.72%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 10.78
# Test Set Loss: 12.02
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 8.10
# Test Set Loss: 9.09
# Train set accuracy for a single minibatch: 89.84%
# Test set accuracy for a single minibatch: 87.50%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 9.10
# Test Set Loss: 7.07
# Train set accuracy for a single minibatch: 87.50%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 7.55
# Test Set Loss: 6.40
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 9.23
# Test Set Loss: 9.93
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 3.81
# Test Set Loss: 5.95
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 7.56
# Test Set Loss: 6.52
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 3.98
# Test Set Loss: 5.13
# Train set accuracy for a single minibatch: 96.09%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 6.68
# Test Set Loss: 3.39
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Total correctly classified test set images: 9356/10000
# Test Set Accuracy: 93.56%
# Finished Net#9
# Epoch 0, Iteration 0
# Train Set Loss: 55.96
# Test Set Loss: 54.58
# Train set accuracy for a single minibatch: 6.25%
# Test set accuracy for a single minibatch: 7.81%
#
#
# Epoch 0, Iteration 50
# Train Set Loss: 8.98
# Test Set Loss: 10.64
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 89.06%
#
#
# Epoch 0, Iteration 100
# Train Set Loss: 8.51
# Test Set Loss: 11.50
# Train set accuracy for a single minibatch: 92.19%
# Test set accuracy for a single minibatch: 86.72%
#
#
# Epoch 0, Iteration 150
# Train Set Loss: 7.79
# Test Set Loss: 10.81
# Train set accuracy for a single minibatch: 89.06%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 200
# Train Set Loss: 6.23
# Test Set Loss: 8.26
# Train set accuracy for a single minibatch: 92.97%
# Test set accuracy for a single minibatch: 91.41%
#
#
# Epoch 0, Iteration 250
# Train Set Loss: 5.76
# Test Set Loss: 5.16
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 300
# Train Set Loss: 6.40
# Test Set Loss: 8.08
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 92.19%
#
#
# Epoch 0, Iteration 350
# Train Set Loss: 4.32
# Test Set Loss: 6.76
# Train set accuracy for a single minibatch: 91.41%
# Test set accuracy for a single minibatch: 92.97%
#
#
# Epoch 0, Iteration 400
# Train Set Loss: 8.04
# Test Set Loss: 5.83
# Train set accuracy for a single minibatch: 93.75%
# Test set accuracy for a single minibatch: 89.84%
#
#
# Epoch 0, Iteration 450
# Train Set Loss: 4.30
# Test Set Loss: 6.09
# Train set accuracy for a single minibatch: 94.53%
# Test set accuracy for a single minibatch: 90.62%
#
#
# Total correctly classified test set images: 9238/10000
# Test Set Accuracy: 92.38%
# Finished Net#10
