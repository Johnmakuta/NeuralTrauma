# %%
# Main Setup

# imports
import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import numpy as np
import itertools

# dataloader arguments
batch_size = 128
data_path='/tmp/data/mnist'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
            transforms.Resize((28, 28)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Network Architecture
num_inputs = 28*28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.70

R = 1
C = 1.44

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Lapicque(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Lapicque(R=R, C=C)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_lapicque()
        mem2 = self.lif2.init_lapicque()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
# Testing Setup

test_net = Net()

test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

test_net.to(device)


print("Testing Loaded Network")


def acc_test(net, mnist_test, batch_size):
    # Test Accuracy

    total = 0
    correct = 0

    # drop_last switched to False to keep all samples
    test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

    with torch.no_grad():
        net.eval()
        for data, targets in test_loader:
            data = data.to(device)
            targets = targets.to(device)
            
            # forward pass
            test_spk, _ = net(data.view(data.size(0), -1))

            # calculate total accuracy
            _, predicted = test_spk.sum(dim=0).max(1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    # print(f"Total correctly classified test set images: {correct}/{total}")
    # print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
    return 100 * correct / total

def mod_fc1(net, neuron_index): # neuron_index 0 to 999
    # Print the initial weights
    # print("Initial weights:", net.fc1.weight)

    # Access the parameters
    parameters = net.parameters()

    # Assuming you want to modify the weights of the first neuron in the linear layer
    # neuron_index = 1    # 0 to 999
    for param in parameters:
        if param is net.fc1.weight:
            # Modify the weights of the first neuron
            new_weights = torch.randn(param.size(1))  # Example: Initialize new weights randomly
            param.data[neuron_index] = new_weights

    # Print the modified weights
    # print("Modified weights:", net.fc1.weight)
    # print("Size of Weights: ", net.fc1.weight.size())
    return net

def mod_fc2(net, neuron_index): # neuron_index 0 to 9
    # Print the initial weights
    # print("Initial weights:", net.fc2.weight)

    # Access the parameters
    parameters = net.parameters()

    # Assuming you want to modify the weights of the first neuron in the linear layer
    # neuron_index = 4     # 0 to 9
    for param in parameters:
        if param is net.fc2.weight:
            # Modify the weights of the first neuron
            new_weights = torch.randn(param.size(1))  # Example: Initialize new weights randomly
            param.data[neuron_index] = new_weights

    # Print the modified weights
    # print("Modified weights:", net.fc2.weight)
    # print("Size of Weights: ", net.fc2.weight.size())
    return net
# Out:
# Testing Loaded Network
# /tmp/ipykernel_12191/1317753921.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

# %%
# Hidden Layer Corruption

fc1_acc_loss_rec = []


test_net = Net()

test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

test_net.to(device)

neuron = 0

acc_ref = acc_test(test_net, mnist_test, batch_size)
print(f"Base Accuracy: {(acc_ref):.2f}%")
for x in range(0,1000):
    acc = acc_test(mod_fc1(test_net, neuron), mnist_test, batch_size)
    print(f"Accuracy loss of Hidden Layer Parameter Corruption({x}): {(acc_ref-acc):.2f}%")
    fc1_acc_loss_rec.append(acc_ref-acc)
# Out:
# /tmp/ipykernel_12191/2748073897.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))
# Base Accuracy: 91.25%
# Accuracy loss of Hidden Layer Parameter Corruption(0): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(1): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(2): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(3): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(4): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(5): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(6): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(7): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(8): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(9): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(10): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(11): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(12): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(13): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(14): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(15): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(16): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(17): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(18): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(19): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(20): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(21): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(22): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(23): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(24): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(25): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(26): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(27): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(28): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(29): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(30): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(31): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(32): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(33): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(34): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(35): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(36): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(37): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(38): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(39): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(40): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(41): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(42): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(43): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(44): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(45): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(46): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(47): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(48): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(49): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(50): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(51): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(52): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(53): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(54): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(55): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(56): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(57): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(58): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(59): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(60): -0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(61): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(62): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(63): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(64): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(65): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(66): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(67): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(68): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(69): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(70): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(71): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(72): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(73): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(74): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(75): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(76): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(77): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(78): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(79): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(80): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(81): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(82): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(83): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(84): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(85): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(86): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(87): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(88): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(89): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(90): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(91): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(92): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(93): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(94): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(95): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(96): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(97): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(98): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(99): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(100): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(101): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(102): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(103): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(104): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(105): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(106): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(107): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(108): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(109): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(110): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(111): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(112): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(113): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(114): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(115): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(116): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(117): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(118): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(119): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(120): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(121): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(122): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(123): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(124): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(125): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(126): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(127): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(128): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(129): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(130): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(131): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(132): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(133): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(134): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(135): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(136): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(137): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(138): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(139): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(140): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(141): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(142): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(143): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(144): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(145): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(146): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(147): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(148): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(149): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(150): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(151): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(152): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(153): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(154): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(155): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(156): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(157): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(158): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(159): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(160): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(161): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(162): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(163): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(164): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(165): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(166): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(167): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(168): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(169): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(170): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(171): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(172): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(173): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(174): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(175): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(176): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(177): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(178): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(179): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(180): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(181): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(182): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(183): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(184): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(185): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(186): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(187): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(188): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(189): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(190): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(191): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(192): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(193): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(194): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(195): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(196): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(197): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(198): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(199): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(200): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(201): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(202): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(203): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(204): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(205): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(206): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(207): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(208): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(209): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(210): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(211): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(212): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(213): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(214): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(215): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(216): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(217): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(218): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(219): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(220): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(221): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(222): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(223): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(224): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(225): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(226): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(227): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(228): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(229): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(230): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(231): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(232): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(233): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(234): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(235): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(236): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(237): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(238): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(239): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(240): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(241): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(242): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(243): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(244): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(245): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(246): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(247): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(248): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(249): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(250): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(251): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(252): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(253): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(254): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(255): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(256): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(257): -0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(258): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(259): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(260): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(261): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(262): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(263): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(264): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(265): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(266): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(267): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(268): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(269): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(270): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(271): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(272): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(273): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(274): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(275): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(276): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(277): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(278): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(279): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(280): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(281): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(282): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(283): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(284): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(285): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(286): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(287): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(288): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(289): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(290): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(291): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(292): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(293): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(294): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(295): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(296): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(297): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(298): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(299): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(300): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(301): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(302): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(303): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(304): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(305): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(306): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(307): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(308): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(309): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(310): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(311): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(312): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(313): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(314): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(315): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(316): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(317): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(318): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(319): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(320): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(321): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(322): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(323): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(324): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(325): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(326): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(327): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(328): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(329): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(330): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(331): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(332): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(333): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(334): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(335): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(336): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(337): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(338): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(339): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(340): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(341): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(342): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(343): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(344): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(345): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(346): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(347): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(348): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(349): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(350): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(351): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(352): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(353): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(354): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(355): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(356): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(357): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(358): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(359): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(360): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(361): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(362): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(363): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(364): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(365): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(366): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(367): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(368): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(369): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(370): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(371): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(372): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(373): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(374): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(375): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(376): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(377): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(378): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(379): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(380): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(381): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(382): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(383): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(384): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(385): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(386): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(387): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(388): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(389): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(390): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(391): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(392): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(393): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(394): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(395): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(396): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(397): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(398): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(399): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(400): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(401): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(402): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(403): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(404): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(405): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(406): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(407): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(408): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(409): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(410): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(411): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(412): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(413): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(414): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(415): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(416): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(417): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(418): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(419): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(420): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(421): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(422): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(423): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(424): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(425): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(426): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(427): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(428): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(429): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(430): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(431): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(432): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(433): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(434): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(435): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(436): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(437): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(438): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(439): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(440): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(441): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(442): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(443): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(444): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(445): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(446): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(447): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(448): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(449): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(450): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(451): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(452): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(453): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(454): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(455): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(456): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(457): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(458): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(459): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(460): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(461): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(462): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(463): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(464): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(465): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(466): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(467): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(468): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(469): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(470): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(471): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(472): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(473): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(474): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(475): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(476): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(477): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(478): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(479): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(480): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(481): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(482): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(483): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(484): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(485): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(486): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(487): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(488): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(489): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(490): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(491): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(492): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(493): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(494): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(495): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(496): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(497): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(498): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(499): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(500): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(501): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(502): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(503): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(504): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(505): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(506): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(507): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(508): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(509): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(510): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(511): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(512): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(513): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(514): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(515): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(516): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(517): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(518): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(519): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(520): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(521): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(522): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(523): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(524): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(525): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(526): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(527): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(528): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(529): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(530): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(531): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(532): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(533): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(534): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(535): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(536): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(537): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(538): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(539): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(540): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(541): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(542): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(543): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(544): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(545): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(546): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(547): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(548): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(549): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(550): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(551): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(552): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(553): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(554): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(555): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(556): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(557): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(558): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(559): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(560): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(561): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(562): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(563): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(564): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(565): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(566): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(567): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(568): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(569): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(570): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(571): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(572): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(573): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(574): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(575): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(576): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(577): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(578): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(579): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(580): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(581): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(582): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(583): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(584): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(585): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(586): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(587): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(588): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(589): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(590): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(591): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(592): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(593): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(594): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(595): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(596): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(597): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(598): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(599): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(600): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(601): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(602): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(603): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(604): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(605): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(606): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(607): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(608): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(609): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(610): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(611): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(612): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(613): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(614): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(615): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(616): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(617): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(618): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(619): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(620): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(621): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(622): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(623): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(624): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(625): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(626): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(627): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(628): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(629): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(630): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(631): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(632): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(633): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(634): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(635): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(636): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(637): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(638): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(639): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(640): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(641): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(642): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(643): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(644): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(645): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(646): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(647): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(648): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(649): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(650): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(651): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(652): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(653): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(654): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(655): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(656): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(657): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(658): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(659): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(660): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(661): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(662): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(663): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(664): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(665): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(666): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(667): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(668): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(669): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(670): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(671): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(672): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(673): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(674): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(675): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(676): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(677): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(678): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(679): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(680): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(681): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(682): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(683): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(684): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(685): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(686): -0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(687): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(688): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(689): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(690): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(691): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(692): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(693): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(694): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(695): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(696): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(697): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(698): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(699): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(700): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(701): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(702): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(703): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(704): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(705): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(706): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(707): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(708): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(709): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(710): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(711): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(712): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(713): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(714): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(715): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(716): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(717): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(718): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(719): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(720): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(721): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(722): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(723): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(724): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(725): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(726): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(727): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(728): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(729): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(730): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(731): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(732): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(733): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(734): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(735): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(736): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(737): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(738): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(739): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(740): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(741): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(742): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(743): -0.01%
# ...
# Accuracy loss of Hidden Layer Parameter Corruption(747): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(748): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(749): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(750): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(751): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(752): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(753): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(754): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(755): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(756): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(757): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(758): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(759): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(760): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(761): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(762): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(763): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(764): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(765): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(766): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(767): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(768): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(769): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(770): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(771): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(772): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(773): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(774): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(775): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(776): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(777): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(778): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(779): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(780): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(781): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(782): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(783): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(784): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(785): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(786): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(787): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(788): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(789): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(790): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(791): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(792): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(793): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(794): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(795): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(796): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(797): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(798): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(799): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(800): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(801): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(802): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(803): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(804): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(805): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(806): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(807): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(808): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(809): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(810): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(811): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(812): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(813): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(814): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(815): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(816): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(817): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(818): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(819): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(820): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(821): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(822): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(823): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(824): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(825): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(826): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(827): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(828): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(829): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(830): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(831): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(832): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(833): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(834): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(835): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(836): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(837): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(838): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(839): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(840): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(841): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(842): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(843): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(844): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(845): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(846): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(847): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(848): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(849): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(850): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(851): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(852): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(853): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(854): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(855): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(856): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(857): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(858): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(859): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(860): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(861): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(862): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(863): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(864): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(865): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(866): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(867): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(868): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(869): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(870): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(871): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(872): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(873): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(874): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(875): -0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(876): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(877): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(878): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(879): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(880): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(881): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(882): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(883): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(884): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(885): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(886): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(887): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(888): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(889): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(890): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(891): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(892): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(893): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(894): -0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(895): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(896): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(897): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(898): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(899): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(900): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(901): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(902): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(903): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(904): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(905): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(906): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(907): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(908): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(909): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(910): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(911): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(912): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(913): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(914): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(915): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(916): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(917): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(918): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(919): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(920): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(921): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(922): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(923): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(924): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(925): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(926): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(927): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(928): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(929): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(930): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(931): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(932): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(933): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(934): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(935): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(936): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(937): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(938): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(939): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(940): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(941): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(942): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(943): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(944): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(945): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(946): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(947): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(948): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(949): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(950): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(951): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(952): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(953): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(954): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(955): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(956): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(957): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(958): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(959): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(960): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(961): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(962): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(963): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(964): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(965): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(966): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(967): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(968): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(969): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(970): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(971): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(972): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(973): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(974): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(975): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(976): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(977): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(978): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(979): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(980): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(981): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(982): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(983): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(984): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(985): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(986): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(987): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(988): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(989): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(990): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(991): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(992): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(993): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(994): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(995): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(996): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(997): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(998): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(999): 0.01%

# %%
print(max(fc1_acc_loss_rec))
# Out:
# 0.09000000000000341
