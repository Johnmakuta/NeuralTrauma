# %%
# Main Setup

# imports
import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import matplotlib.pyplot as plt
import numpy as np
import itertools

# dataloader arguments
batch_size = 128
data_path='/tmp/data/mnist'

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")

# Define a transform
transform = transforms.Compose([
            transforms.Resize((28, 28)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)

# Create DataLoaders
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# Network Architecture
num_inputs = 28*28
num_hidden = 1000
num_outputs = 10

# Temporal Dynamics
num_steps = 25
beta = 0.70

R = 1
C = 1.44

# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

        # Initialize layers
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        self.lif1 = snn.Lapicque(beta=beta)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        self.lif2 = snn.Lapicque(R=R, C=C)

    def forward(self, x):

        # Initialize hidden states at t=0
        mem1 = self.lif1.init_lapicque()
        mem2 = self.lif2.init_lapicque()

        # Record the final layer
        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, mem1 = self.lif1(cur1, mem1)
            cur2 = self.fc2(spk1)
            spk2, mem2 = self.lif2(cur2, mem2)
            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

# %%
# Testing Setup

test_net = Net()

test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

test_net.to(device)


print("Testing Loaded Network")


def acc_test(net, mnist_test, batch_size):
    # Test Accuracy

    total = 0
    correct = 0

    # drop_last switched to False to keep all samples
    test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

    with torch.no_grad():
        net.eval()
        for data, targets in test_loader:
            data = data.to(device)
            targets = targets.to(device)
            
            # forward pass
            test_spk, _ = net(data.view(data.size(0), -1))

            # calculate total accuracy
            _, predicted = test_spk.sum(dim=0).max(1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    # print(f"Total correctly classified test set images: {correct}/{total}")
    # print(f"Test Set Accuracy: {100 * correct / total:.2f}%")
    return 100 * correct / total

def mod_fc1(net, neuron_index): # neuron_index 0 to 999
    # Print the initial weights
    # print("Initial weights:", net.fc1.weight)

    # Access the parameters
    parameters = net.parameters()

    # Assuming you want to modify the weights of the first neuron in the linear layer
    # neuron_index = 1    # 0 to 999
    for param in parameters:
        if param is net.fc1.weight:
            # Modify the weights of the first neuron
            new_weights = torch.randn(param.size(1))  # Example: Initialize new weights randomly
            param.data[neuron_index] = new_weights

    # Print the modified weights
    # print("Modified weights:", net.fc1.weight)
    # print("Size of Weights: ", net.fc1.weight.size())
    return net

def mod_fc2(net, neuron_index): # neuron_index 0 to 9
    # Print the initial weights
    # print("Initial weights:", net.fc2.weight)

    # Access the parameters
    parameters = net.parameters()

    # Assuming you want to modify the weights of the first neuron in the linear layer
    # neuron_index = 4     # 0 to 9
    for param in parameters:
        if param is net.fc2.weight:
            # Modify the weights of the first neuron
            new_weights = torch.randn(param.size(1))  # Example: Initialize new weights randomly
            param.data[neuron_index] = new_weights

    # Print the modified weights
    # print("Modified weights:", net.fc2.weight)
    # print("Size of Weights: ", net.fc2.weight.size())
    return net
# Out:
# Testing Loaded Network
# /tmp/ipykernel_12191/1317753921.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

# %%
# Hidden Layer Corruption

fc1_acc_loss_rec = []


test_net = Net()

test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))

test_net.to(device)



acc_ref = acc_test(test_net, mnist_test, batch_size)
print(f"Base Accuracy: {(acc_ref):.2f}%")
for x in range(0,1000):
    acc = acc_test(mod_fc1(test_net, x), mnist_test, batch_size)
    print(f"Accuracy loss of Hidden Layer Parameter Corruption({x}): {(acc_ref-acc):.2f}%")
    fc1_acc_loss_rec.append(acc_ref-acc)
# Out:
# /tmp/ipykernel_12191/3106554180.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   test_net.load_state_dict(torch.load('net_generators/ref_snn_lapicque_0.pth'))
# Base Accuracy: 91.25%
# Accuracy loss of Hidden Layer Parameter Corruption(0): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(1): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(2): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(3): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(4): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(5): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(6): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(7): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(8): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(9): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(10): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(11): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(12): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(13): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(14): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(15): 0.15%
# Accuracy loss of Hidden Layer Parameter Corruption(16): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(17): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(18): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(19): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(20): 0.23%
# Accuracy loss of Hidden Layer Parameter Corruption(21): 0.30%
# Accuracy loss of Hidden Layer Parameter Corruption(22): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(23): 0.23%
# Accuracy loss of Hidden Layer Parameter Corruption(24): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(25): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(26): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(27): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(28): 0.15%
# Accuracy loss of Hidden Layer Parameter Corruption(29): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(30): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(31): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(32): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(33): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(34): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(35): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(36): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(37): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(38): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(39): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(40): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(41): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(42): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(43): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(44): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(45): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(46): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(47): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(48): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(49): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(50): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(51): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(52): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(53): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(54): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(55): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(56): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(57): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(58): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(59): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(60): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(61): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(62): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(63): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(64): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(65): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(66): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(67): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(68): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(69): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(70): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(71): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(72): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(73): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(74): 0.15%
# Accuracy loss of Hidden Layer Parameter Corruption(75): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(76): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(77): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(78): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(79): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(80): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(81): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(82): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(83): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(84): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(85): 0.23%
# Accuracy loss of Hidden Layer Parameter Corruption(86): 0.25%
# Accuracy loss of Hidden Layer Parameter Corruption(87): 0.21%
# Accuracy loss of Hidden Layer Parameter Corruption(88): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(89): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(90): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(91): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(92): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(93): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(94): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(95): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(96): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(97): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(98): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(99): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(100): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(101): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(102): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(103): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(104): 0.27%
# Accuracy loss of Hidden Layer Parameter Corruption(105): 0.28%
# Accuracy loss of Hidden Layer Parameter Corruption(106): 0.26%
# Accuracy loss of Hidden Layer Parameter Corruption(107): 0.32%
# Accuracy loss of Hidden Layer Parameter Corruption(108): 0.31%
# Accuracy loss of Hidden Layer Parameter Corruption(109): 0.25%
# Accuracy loss of Hidden Layer Parameter Corruption(110): 0.27%
# Accuracy loss of Hidden Layer Parameter Corruption(111): 0.28%
# Accuracy loss of Hidden Layer Parameter Corruption(112): 0.26%
# Accuracy loss of Hidden Layer Parameter Corruption(113): 0.31%
# Accuracy loss of Hidden Layer Parameter Corruption(114): 0.21%
# Accuracy loss of Hidden Layer Parameter Corruption(115): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(116): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(117): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(118): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(119): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(120): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(121): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(122): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(123): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(124): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(125): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(126): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(127): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(128): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(129): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(130): -0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(131): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(132): -0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(133): -0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(134): 0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(135): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(136): 0.00%
# Accuracy loss of Hidden Layer Parameter Corruption(137): -0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(138): -0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(139): -0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(140): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(141): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(142): -0.04%
# Accuracy loss of Hidden Layer Parameter Corruption(143): -0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(144): -0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(145): -0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(146): -0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(147): -0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(148): -0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(149): 0.01%
# Accuracy loss of Hidden Layer Parameter Corruption(150): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(151): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(152): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(153): 0.02%
# Accuracy loss of Hidden Layer Parameter Corruption(154): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(155): 0.05%
# Accuracy loss of Hidden Layer Parameter Corruption(156): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(157): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(158): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(159): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(160): 0.03%
# Accuracy loss of Hidden Layer Parameter Corruption(161): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(162): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(163): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(164): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(165): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(166): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(167): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(168): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(169): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(170): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(171): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(172): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(173): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(174): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(175): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(176): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(177): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(178): 0.06%
# Accuracy loss of Hidden Layer Parameter Corruption(179): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(180): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(181): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(182): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(183): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(184): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(185): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(186): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(187): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(188): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(189): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(190): 0.19%
# Accuracy loss of Hidden Layer Parameter Corruption(191): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(192): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(193): 0.13%
# Accuracy loss of Hidden Layer Parameter Corruption(194): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(195): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(196): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(197): 0.17%
# Accuracy loss of Hidden Layer Parameter Corruption(198): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(199): 0.20%
# Accuracy loss of Hidden Layer Parameter Corruption(200): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(201): 0.15%
# Accuracy loss of Hidden Layer Parameter Corruption(202): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(203): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(204): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(205): 0.11%
# Accuracy loss of Hidden Layer Parameter Corruption(206): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(207): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(208): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(209): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(210): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(211): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(212): 0.10%
# Accuracy loss of Hidden Layer Parameter Corruption(213): 0.14%
# Accuracy loss of Hidden Layer Parameter Corruption(214): 0.09%
# Accuracy loss of Hidden Layer Parameter Corruption(215): 0.08%
# Accuracy loss of Hidden Layer Parameter Corruption(216): 0.07%
# Accuracy loss of Hidden Layer Parameter Corruption(217): 0.16%
# Accuracy loss of Hidden Layer Parameter Corruption(218): 0.12%
# Accuracy loss of Hidden Layer Parameter Corruption(219): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(220): 0.18%
# Accuracy loss of Hidden Layer Parameter Corruption(221): 0.23%
# Accuracy loss of Hidden Layer Parameter Corruption(222): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(223): 0.25%
# Accuracy loss of Hidden Layer Parameter Corruption(224): 0.26%
# Accuracy loss of Hidden Layer Parameter Corruption(225): 0.27%
# Accuracy loss of Hidden Layer Parameter Corruption(226): 0.27%
# Accuracy loss of Hidden Layer Parameter Corruption(227): 0.25%
# Accuracy loss of Hidden Layer Parameter Corruption(228): 0.25%
# Accuracy loss of Hidden Layer Parameter Corruption(229): 0.27%
# Accuracy loss of Hidden Layer Parameter Corruption(230): 0.24%
# Accuracy loss of Hidden Layer Parameter Corruption(231): 0.22%
# Accuracy loss of Hidden Layer Parameter Corruption(232): 0.26%
# Accuracy loss of Hidden Layer Parameter Corruption(233): 0.30%
# Accuracy loss of Hidden Layer Parameter Corruption(234): 0.32%
# Accuracy loss of Hidden Layer Parameter Corruption(235): 0.32%
# Accuracy loss of Hidden Layer Parameter Corruption(236): 0.30%
# Accuracy loss of Hidden Layer Parameter Corruption(237): 0.37%
# Accuracy loss of Hidden Layer Parameter Corruption(238): 0.37%
# Accuracy loss of Hidden Layer Parameter Corruption(239): 0.38%
# Accuracy loss of Hidden Layer Parameter Corruption(240): 0.43%
# Accuracy loss of Hidden Layer Parameter Corruption(241): 0.37%
# Accuracy loss of Hidden Layer Parameter Corruption(242): 0.40%
# Accuracy loss of Hidden Layer Parameter Corruption(243): 0.43%
# Accuracy loss of Hidden Layer Parameter Corruption(244): 0.41%
# Accuracy loss of Hidden Layer Parameter Corruption(245): 0.40%
# Accuracy loss of Hidden Layer Parameter Corruption(246): 0.41%
# Accuracy loss of Hidden Layer Parameter Corruption(247): 0.42%
# Accuracy loss of Hidden Layer Parameter Corruption(248): 0.43%
# Accuracy loss of Hidden Layer Parameter Corruption(249): 0.39%
# Accuracy loss of Hidden Layer Parameter Corruption(250): 0.44%
# Accuracy loss of Hidden Layer Parameter Corruption(251): 0.47%
# Accuracy loss of Hidden Layer Parameter Corruption(252): 0.48%
# Accuracy loss of Hidden Layer Parameter Corruption(253): 0.46%
# Accuracy loss of Hidden Layer Parameter Corruption(254): 0.49%
# Accuracy loss of Hidden Layer Parameter Corruption(255): 0.50%
# Accuracy loss of Hidden Layer Parameter Corruption(256): 0.53%
# Accuracy loss of Hidden Layer Parameter Corruption(257): 0.67%
# Accuracy loss of Hidden Layer Parameter Corruption(258): 0.54%
# Accuracy loss of Hidden Layer Parameter Corruption(259): 0.52%
# Accuracy loss of Hidden Layer Parameter Corruption(260): 0.56%
# Accuracy loss of Hidden Layer Parameter Corruption(261): 0.53%
# Accuracy loss of Hidden Layer Parameter Corruption(262): 0.52%
# Accuracy loss of Hidden Layer Parameter Corruption(263): 0.58%
# Accuracy loss of Hidden Layer Parameter Corruption(264): 0.57%
# Accuracy loss of Hidden Layer Parameter Corruption(265): 0.64%
# Accuracy loss of Hidden Layer Parameter Corruption(266): 0.75%
# Accuracy loss of Hidden Layer Parameter Corruption(267): 0.76%
# Accuracy loss of Hidden Layer Parameter Corruption(268): 0.77%
# Accuracy loss of Hidden Layer Parameter Corruption(269): 0.80%
# Accuracy loss of Hidden Layer Parameter Corruption(270): 0.81%
# Accuracy loss of Hidden Layer Parameter Corruption(271): 0.76%
# Accuracy loss of Hidden Layer Parameter Corruption(272): 0.76%
# Accuracy loss of Hidden Layer Parameter Corruption(273): 0.80%
# Accuracy loss of Hidden Layer Parameter Corruption(274): 0.85%
# Accuracy loss of Hidden Layer Parameter Corruption(275): 0.81%
# Accuracy loss of Hidden Layer Parameter Corruption(276): 0.85%
# Accuracy loss of Hidden Layer Parameter Corruption(277): 0.90%
# Accuracy loss of Hidden Layer Parameter Corruption(278): 0.86%
# Accuracy loss of Hidden Layer Parameter Corruption(279): 0.87%
# Accuracy loss of Hidden Layer Parameter Corruption(280): 0.87%
# Accuracy loss of Hidden Layer Parameter Corruption(281): 0.98%
# Accuracy loss of Hidden Layer Parameter Corruption(282): 1.01%
# Accuracy loss of Hidden Layer Parameter Corruption(283): 0.96%
# Accuracy loss of Hidden Layer Parameter Corruption(284): 1.02%
# Accuracy loss of Hidden Layer Parameter Corruption(285): 1.05%
# Accuracy loss of Hidden Layer Parameter Corruption(286): 1.04%
# Accuracy loss of Hidden Layer Parameter Corruption(287): 1.01%
# Accuracy loss of Hidden Layer Parameter Corruption(288): 1.06%
# Accuracy loss of Hidden Layer Parameter Corruption(289): 1.02%
# Accuracy loss of Hidden Layer Parameter Corruption(290): 1.10%
# Accuracy loss of Hidden Layer Parameter Corruption(291): 1.06%
# Accuracy loss of Hidden Layer Parameter Corruption(292): 1.03%
# Accuracy loss of Hidden Layer Parameter Corruption(293): 1.07%
# Accuracy loss of Hidden Layer Parameter Corruption(294): 1.09%
# Accuracy loss of Hidden Layer Parameter Corruption(295): 1.13%
# Accuracy loss of Hidden Layer Parameter Corruption(296): 1.13%
# Accuracy loss of Hidden Layer Parameter Corruption(297): 1.12%
# Accuracy loss of Hidden Layer Parameter Corruption(298): 1.23%
# Accuracy loss of Hidden Layer Parameter Corruption(299): 1.21%
# Accuracy loss of Hidden Layer Parameter Corruption(300): 1.21%
# Accuracy loss of Hidden Layer Parameter Corruption(301): 1.19%
# Accuracy loss of Hidden Layer Parameter Corruption(302): 1.18%
# Accuracy loss of Hidden Layer Parameter Corruption(303): 1.28%
# Accuracy loss of Hidden Layer Parameter Corruption(304): 1.43%
# Accuracy loss of Hidden Layer Parameter Corruption(305): 1.54%
# Accuracy loss of Hidden Layer Parameter Corruption(306): 1.69%
# Accuracy loss of Hidden Layer Parameter Corruption(307): 1.66%
# Accuracy loss of Hidden Layer Parameter Corruption(308): 1.74%
# Accuracy loss of Hidden Layer Parameter Corruption(309): 1.82%
# Accuracy loss of Hidden Layer Parameter Corruption(310): 1.90%
# Accuracy loss of Hidden Layer Parameter Corruption(311): 1.86%
# Accuracy loss of Hidden Layer Parameter Corruption(312): 1.85%
# Accuracy loss of Hidden Layer Parameter Corruption(313): 1.87%
# Accuracy loss of Hidden Layer Parameter Corruption(314): 1.92%
# Accuracy loss of Hidden Layer Parameter Corruption(315): 1.94%
# Accuracy loss of Hidden Layer Parameter Corruption(316): 2.02%
# Accuracy loss of Hidden Layer Parameter Corruption(317): 2.10%
# Accuracy loss of Hidden Layer Parameter Corruption(318): 2.11%
# Accuracy loss of Hidden Layer Parameter Corruption(319): 2.10%
# Accuracy loss of Hidden Layer Parameter Corruption(320): 2.15%
# Accuracy loss of Hidden Layer Parameter Corruption(321): 2.18%
# Accuracy loss of Hidden Layer Parameter Corruption(322): 2.22%
# Accuracy loss of Hidden Layer Parameter Corruption(323): 2.26%
# Accuracy loss of Hidden Layer Parameter Corruption(324): 2.25%
# Accuracy loss of Hidden Layer Parameter Corruption(325): 2.29%
# Accuracy loss of Hidden Layer Parameter Corruption(326): 2.41%
# Accuracy loss of Hidden Layer Parameter Corruption(327): 2.42%
# Accuracy loss of Hidden Layer Parameter Corruption(328): 2.38%
# Accuracy loss of Hidden Layer Parameter Corruption(329): 2.42%
# Accuracy loss of Hidden Layer Parameter Corruption(330): 2.37%
# Accuracy loss of Hidden Layer Parameter Corruption(331): 2.47%
# Accuracy loss of Hidden Layer Parameter Corruption(332): 2.40%
# Accuracy loss of Hidden Layer Parameter Corruption(333): 2.43%
# Accuracy loss of Hidden Layer Parameter Corruption(334): 2.44%
# Accuracy loss of Hidden Layer Parameter Corruption(335): 2.48%
# Accuracy loss of Hidden Layer Parameter Corruption(336): 2.53%
# Accuracy loss of Hidden Layer Parameter Corruption(337): 2.52%
# Accuracy loss of Hidden Layer Parameter Corruption(338): 2.59%
# Accuracy loss of Hidden Layer Parameter Corruption(339): 2.62%
# Accuracy loss of Hidden Layer Parameter Corruption(340): 2.65%
# Accuracy loss of Hidden Layer Parameter Corruption(341): 2.68%
# Accuracy loss of Hidden Layer Parameter Corruption(342): 2.71%
# Accuracy loss of Hidden Layer Parameter Corruption(343): 2.81%
# Accuracy loss of Hidden Layer Parameter Corruption(344): 2.83%
# Accuracy loss of Hidden Layer Parameter Corruption(345): 2.95%
# Accuracy loss of Hidden Layer Parameter Corruption(346): 2.95%
# Accuracy loss of Hidden Layer Parameter Corruption(347): 3.02%
# Accuracy loss of Hidden Layer Parameter Corruption(348): 3.05%
# Accuracy loss of Hidden Layer Parameter Corruption(349): 3.15%
# Accuracy loss of Hidden Layer Parameter Corruption(350): 3.29%
# Accuracy loss of Hidden Layer Parameter Corruption(351): 3.28%
# Accuracy loss of Hidden Layer Parameter Corruption(352): 3.38%
# Accuracy loss of Hidden Layer Parameter Corruption(353): 3.49%
# Accuracy loss of Hidden Layer Parameter Corruption(354): 3.55%
# Accuracy loss of Hidden Layer Parameter Corruption(355): 3.73%
# Accuracy loss of Hidden Layer Parameter Corruption(356): 3.80%
# Accuracy loss of Hidden Layer Parameter Corruption(357): 3.97%
# Accuracy loss of Hidden Layer Parameter Corruption(358): 3.97%
# Accuracy loss of Hidden Layer Parameter Corruption(359): 4.02%
# Accuracy loss of Hidden Layer Parameter Corruption(360): 4.04%
# Accuracy loss of Hidden Layer Parameter Corruption(361): 4.13%
# Accuracy loss of Hidden Layer Parameter Corruption(362): 4.25%
# Accuracy loss of Hidden Layer Parameter Corruption(363): 4.42%
# Accuracy loss of Hidden Layer Parameter Corruption(364): 4.45%
# Accuracy loss of Hidden Layer Parameter Corruption(365): 4.44%
# Accuracy loss of Hidden Layer Parameter Corruption(366): 4.58%
# Accuracy loss of Hidden Layer Parameter Corruption(367): 4.68%
# Accuracy loss of Hidden Layer Parameter Corruption(368): 4.70%
# Accuracy loss of Hidden Layer Parameter Corruption(369): 4.80%
# Accuracy loss of Hidden Layer Parameter Corruption(370): 4.72%
# Accuracy loss of Hidden Layer Parameter Corruption(371): 4.72%
# Accuracy loss of Hidden Layer Parameter Corruption(372): 4.70%
# Accuracy loss of Hidden Layer Parameter Corruption(373): 4.68%
# Accuracy loss of Hidden Layer Parameter Corruption(374): 4.89%
# Accuracy loss of Hidden Layer Parameter Corruption(375): 5.07%
# Accuracy loss of Hidden Layer Parameter Corruption(376): 5.12%
# Accuracy loss of Hidden Layer Parameter Corruption(377): 5.12%
# Accuracy loss of Hidden Layer Parameter Corruption(378): 5.23%
# Accuracy loss of Hidden Layer Parameter Corruption(379): 5.29%
# Accuracy loss of Hidden Layer Parameter Corruption(380): 5.30%
# Accuracy loss of Hidden Layer Parameter Corruption(381): 5.31%
# Accuracy loss of Hidden Layer Parameter Corruption(382): 5.54%
# Accuracy loss of Hidden Layer Parameter Corruption(383): 5.49%
# Accuracy loss of Hidden Layer Parameter Corruption(384): 5.47%
# Accuracy loss of Hidden Layer Parameter Corruption(385): 5.64%
# Accuracy loss of Hidden Layer Parameter Corruption(386): 5.74%
# Accuracy loss of Hidden Layer Parameter Corruption(387): 6.02%
# Accuracy loss of Hidden Layer Parameter Corruption(388): 6.14%
# Accuracy loss of Hidden Layer Parameter Corruption(389): 6.21%
# Accuracy loss of Hidden Layer Parameter Corruption(390): 6.32%
# Accuracy loss of Hidden Layer Parameter Corruption(391): 6.51%
# Accuracy loss of Hidden Layer Parameter Corruption(392): 6.51%
# Accuracy loss of Hidden Layer Parameter Corruption(393): 6.55%
# Accuracy loss of Hidden Layer Parameter Corruption(394): 6.70%
# Accuracy loss of Hidden Layer Parameter Corruption(395): 6.75%
# Accuracy loss of Hidden Layer Parameter Corruption(396): 6.83%
# Accuracy loss of Hidden Layer Parameter Corruption(397): 6.82%
# Accuracy loss of Hidden Layer Parameter Corruption(398): 6.93%
# Accuracy loss of Hidden Layer Parameter Corruption(399): 7.05%
# Accuracy loss of Hidden Layer Parameter Corruption(400): 7.07%
# Accuracy loss of Hidden Layer Parameter Corruption(401): 7.15%
# Accuracy loss of Hidden Layer Parameter Corruption(402): 7.21%
# Accuracy loss of Hidden Layer Parameter Corruption(403): 7.22%
# Accuracy loss of Hidden Layer Parameter Corruption(404): 7.29%
# Accuracy loss of Hidden Layer Parameter Corruption(405): 7.55%
# Accuracy loss of Hidden Layer Parameter Corruption(406): 7.76%
# Accuracy loss of Hidden Layer Parameter Corruption(407): 7.82%
# Accuracy loss of Hidden Layer Parameter Corruption(408): 8.05%
# Accuracy loss of Hidden Layer Parameter Corruption(409): 8.13%
# Accuracy loss of Hidden Layer Parameter Corruption(410): 8.20%
# Accuracy loss of Hidden Layer Parameter Corruption(411): 8.22%
# Accuracy loss of Hidden Layer Parameter Corruption(412): 8.34%
# Accuracy loss of Hidden Layer Parameter Corruption(413): 8.54%
# Accuracy loss of Hidden Layer Parameter Corruption(414): 8.55%
# Accuracy loss of Hidden Layer Parameter Corruption(415): 8.73%
# Accuracy loss of Hidden Layer Parameter Corruption(416): 8.76%
# Accuracy loss of Hidden Layer Parameter Corruption(417): 9.14%
# Accuracy loss of Hidden Layer Parameter Corruption(418): 9.29%
# Accuracy loss of Hidden Layer Parameter Corruption(419): 9.41%
# Accuracy loss of Hidden Layer Parameter Corruption(420): 9.47%
# Accuracy loss of Hidden Layer Parameter Corruption(421): 9.51%
# Accuracy loss of Hidden Layer Parameter Corruption(422): 9.69%
# Accuracy loss of Hidden Layer Parameter Corruption(423): 9.82%
# Accuracy loss of Hidden Layer Parameter Corruption(424): 9.88%
# Accuracy loss of Hidden Layer Parameter Corruption(425): 9.98%
# Accuracy loss of Hidden Layer Parameter Corruption(426): 10.04%
# Accuracy loss of Hidden Layer Parameter Corruption(427): 10.14%
# Accuracy loss of Hidden Layer Parameter Corruption(428): 10.28%
# Accuracy loss of Hidden Layer Parameter Corruption(429): 10.59%
# Accuracy loss of Hidden Layer Parameter Corruption(430): 10.66%
# Accuracy loss of Hidden Layer Parameter Corruption(431): 10.91%
# Accuracy loss of Hidden Layer Parameter Corruption(432): 10.88%
# Accuracy loss of Hidden Layer Parameter Corruption(433): 11.11%
# Accuracy loss of Hidden Layer Parameter Corruption(434): 11.15%
# Accuracy loss of Hidden Layer Parameter Corruption(435): 11.45%
# Accuracy loss of Hidden Layer Parameter Corruption(436): 11.65%
# Accuracy loss of Hidden Layer Parameter Corruption(437): 11.75%
# Accuracy loss of Hidden Layer Parameter Corruption(438): 11.82%
# Accuracy loss of Hidden Layer Parameter Corruption(439): 12.19%
# Accuracy loss of Hidden Layer Parameter Corruption(440): 12.35%
# Accuracy loss of Hidden Layer Parameter Corruption(441): 12.60%
# Accuracy loss of Hidden Layer Parameter Corruption(442): 12.68%
# Accuracy loss of Hidden Layer Parameter Corruption(443): 13.07%
# Accuracy loss of Hidden Layer Parameter Corruption(444): 13.47%
# Accuracy loss of Hidden Layer Parameter Corruption(445): 13.50%
# Accuracy loss of Hidden Layer Parameter Corruption(446): 13.69%
# Accuracy loss of Hidden Layer Parameter Corruption(447): 13.69%
# Accuracy loss of Hidden Layer Parameter Corruption(448): 13.75%
# Accuracy loss of Hidden Layer Parameter Corruption(449): 13.90%
# Accuracy loss of Hidden Layer Parameter Corruption(450): 14.01%
# Accuracy loss of Hidden Layer Parameter Corruption(451): 14.09%
# Accuracy loss of Hidden Layer Parameter Corruption(452): 14.19%
# Accuracy loss of Hidden Layer Parameter Corruption(453): 14.31%
# Accuracy loss of Hidden Layer Parameter Corruption(454): 14.43%
# Accuracy loss of Hidden Layer Parameter Corruption(455): 14.67%
# Accuracy loss of Hidden Layer Parameter Corruption(456): 15.02%
# Accuracy loss of Hidden Layer Parameter Corruption(457): 14.82%
# Accuracy loss of Hidden Layer Parameter Corruption(458): 14.64%
# Accuracy loss of Hidden Layer Parameter Corruption(459): 14.89%
# Accuracy loss of Hidden Layer Parameter Corruption(460): 15.08%
# Accuracy loss of Hidden Layer Parameter Corruption(461): 15.21%
# Accuracy loss of Hidden Layer Parameter Corruption(462): 15.43%
# Accuracy loss of Hidden Layer Parameter Corruption(463): 15.56%
# Accuracy loss of Hidden Layer Parameter Corruption(464): 15.82%
# Accuracy loss of Hidden Layer Parameter Corruption(465): 16.11%
# Accuracy loss of Hidden Layer Parameter Corruption(466): 16.19%
# Accuracy loss of Hidden Layer Parameter Corruption(467): 16.31%
# Accuracy loss of Hidden Layer Parameter Corruption(468): 16.40%
# Accuracy loss of Hidden Layer Parameter Corruption(469): 16.43%
# Accuracy loss of Hidden Layer Parameter Corruption(470): 16.59%
# Accuracy loss of Hidden Layer Parameter Corruption(471): 16.73%
# Accuracy loss of Hidden Layer Parameter Corruption(472): 17.24%
# Accuracy loss of Hidden Layer Parameter Corruption(473): 17.60%
# Accuracy loss of Hidden Layer Parameter Corruption(474): 17.69%
# Accuracy loss of Hidden Layer Parameter Corruption(475): 17.70%
# Accuracy loss of Hidden Layer Parameter Corruption(476): 17.84%
# Accuracy loss of Hidden Layer Parameter Corruption(477): 18.14%
# Accuracy loss of Hidden Layer Parameter Corruption(478): 18.69%
# Accuracy loss of Hidden Layer Parameter Corruption(479): 19.28%
# Accuracy loss of Hidden Layer Parameter Corruption(480): 19.55%
# Accuracy loss of Hidden Layer Parameter Corruption(481): 19.58%
# Accuracy loss of Hidden Layer Parameter Corruption(482): 19.81%
# Accuracy loss of Hidden Layer Parameter Corruption(483): 20.34%
# Accuracy loss of Hidden Layer Parameter Corruption(484): 20.60%
# Accuracy loss of Hidden Layer Parameter Corruption(485): 20.95%
# Accuracy loss of Hidden Layer Parameter Corruption(486): 21.18%
# Accuracy loss of Hidden Layer Parameter Corruption(487): 21.40%
# Accuracy loss of Hidden Layer Parameter Corruption(488): 21.57%
# Accuracy loss of Hidden Layer Parameter Corruption(489): 21.71%
# Accuracy loss of Hidden Layer Parameter Corruption(490): 22.14%
# Accuracy loss of Hidden Layer Parameter Corruption(491): 22.62%
# Accuracy loss of Hidden Layer Parameter Corruption(492): 22.78%
# Accuracy loss of Hidden Layer Parameter Corruption(493): 22.93%
# Accuracy loss of Hidden Layer Parameter Corruption(494): 22.97%
# Accuracy loss of Hidden Layer Parameter Corruption(495): 23.57%
# Accuracy loss of Hidden Layer Parameter Corruption(496): 23.99%
# Accuracy loss of Hidden Layer Parameter Corruption(497): 24.24%
# Accuracy loss of Hidden Layer Parameter Corruption(498): 24.38%
# Accuracy loss of Hidden Layer Parameter Corruption(499): 24.40%
# Accuracy loss of Hidden Layer Parameter Corruption(500): 24.73%
# Accuracy loss of Hidden Layer Parameter Corruption(501): 25.16%
# Accuracy loss of Hidden Layer Parameter Corruption(502): 25.24%
# Accuracy loss of Hidden Layer Parameter Corruption(503): 25.60%
# Accuracy loss of Hidden Layer Parameter Corruption(504): 25.68%
# Accuracy loss of Hidden Layer Parameter Corruption(505): 25.93%
# Accuracy loss of Hidden Layer Parameter Corruption(506): 26.24%
# Accuracy loss of Hidden Layer Parameter Corruption(507): 26.35%
# Accuracy loss of Hidden Layer Parameter Corruption(508): 26.92%
# Accuracy loss of Hidden Layer Parameter Corruption(509): 27.26%
# Accuracy loss of Hidden Layer Parameter Corruption(510): 27.36%
# Accuracy loss of Hidden Layer Parameter Corruption(511): 28.12%
# Accuracy loss of Hidden Layer Parameter Corruption(512): 28.35%
# Accuracy loss of Hidden Layer Parameter Corruption(513): 28.41%
# Accuracy loss of Hidden Layer Parameter Corruption(514): 28.56%
# Accuracy loss of Hidden Layer Parameter Corruption(515): 28.83%
# Accuracy loss of Hidden Layer Parameter Corruption(516): 29.20%
# Accuracy loss of Hidden Layer Parameter Corruption(517): 29.58%
# Accuracy loss of Hidden Layer Parameter Corruption(518): 29.87%
# Accuracy loss of Hidden Layer Parameter Corruption(519): 29.97%
# Accuracy loss of Hidden Layer Parameter Corruption(520): 30.06%
# Accuracy loss of Hidden Layer Parameter Corruption(521): 30.44%
# Accuracy loss of Hidden Layer Parameter Corruption(522): 30.83%
# Accuracy loss of Hidden Layer Parameter Corruption(523): 30.80%
# Accuracy loss of Hidden Layer Parameter Corruption(524): 31.31%
# Accuracy loss of Hidden Layer Parameter Corruption(525): 31.89%
# Accuracy loss of Hidden Layer Parameter Corruption(526): 32.48%
# Accuracy loss of Hidden Layer Parameter Corruption(527): 32.66%
# Accuracy loss of Hidden Layer Parameter Corruption(528): 32.98%
# Accuracy loss of Hidden Layer Parameter Corruption(529): 33.30%
# Accuracy loss of Hidden Layer Parameter Corruption(530): 33.41%
# Accuracy loss of Hidden Layer Parameter Corruption(531): 33.83%
# Accuracy loss of Hidden Layer Parameter Corruption(532): 34.07%
# Accuracy loss of Hidden Layer Parameter Corruption(533): 34.30%
# Accuracy loss of Hidden Layer Parameter Corruption(534): 34.93%
# Accuracy loss of Hidden Layer Parameter Corruption(535): 35.30%
# Accuracy loss of Hidden Layer Parameter Corruption(536): 35.60%
# Accuracy loss of Hidden Layer Parameter Corruption(537): 35.82%
# Accuracy loss of Hidden Layer Parameter Corruption(538): 35.87%
# Accuracy loss of Hidden Layer Parameter Corruption(539): 35.84%
# Accuracy loss of Hidden Layer Parameter Corruption(540): 36.24%
# Accuracy loss of Hidden Layer Parameter Corruption(541): 36.44%
# Accuracy loss of Hidden Layer Parameter Corruption(542): 36.64%
# Accuracy loss of Hidden Layer Parameter Corruption(543): 36.91%
# Accuracy loss of Hidden Layer Parameter Corruption(544): 37.42%
# Accuracy loss of Hidden Layer Parameter Corruption(545): 37.57%
# Accuracy loss of Hidden Layer Parameter Corruption(546): 37.79%
# Accuracy loss of Hidden Layer Parameter Corruption(547): 37.96%
# Accuracy loss of Hidden Layer Parameter Corruption(548): 38.27%
# Accuracy loss of Hidden Layer Parameter Corruption(549): 38.63%
# Accuracy loss of Hidden Layer Parameter Corruption(550): 38.88%
# Accuracy loss of Hidden Layer Parameter Corruption(551): 39.14%
# Accuracy loss of Hidden Layer Parameter Corruption(552): 39.57%
# Accuracy loss of Hidden Layer Parameter Corruption(553): 39.96%
# Accuracy loss of Hidden Layer Parameter Corruption(554): 40.53%
# Accuracy loss of Hidden Layer Parameter Corruption(555): 41.03%
# Accuracy loss of Hidden Layer Parameter Corruption(556): 41.27%
# Accuracy loss of Hidden Layer Parameter Corruption(557): 41.37%
# Accuracy loss of Hidden Layer Parameter Corruption(558): 41.76%
# Accuracy loss of Hidden Layer Parameter Corruption(559): 41.97%
# Accuracy loss of Hidden Layer Parameter Corruption(560): 42.29%
# Accuracy loss of Hidden Layer Parameter Corruption(561): 42.88%
# Accuracy loss of Hidden Layer Parameter Corruption(562): 43.11%
# Accuracy loss of Hidden Layer Parameter Corruption(563): 43.24%
# Accuracy loss of Hidden Layer Parameter Corruption(564): 43.47%
# Accuracy loss of Hidden Layer Parameter Corruption(565): 43.64%
# Accuracy loss of Hidden Layer Parameter Corruption(566): 44.15%
# Accuracy loss of Hidden Layer Parameter Corruption(567): 44.24%
# Accuracy loss of Hidden Layer Parameter Corruption(568): 44.34%
# Accuracy loss of Hidden Layer Parameter Corruption(569): 44.55%
# Accuracy loss of Hidden Layer Parameter Corruption(570): 44.64%
# Accuracy loss of Hidden Layer Parameter Corruption(571): 44.87%
# Accuracy loss of Hidden Layer Parameter Corruption(572): 45.10%
# Accuracy loss of Hidden Layer Parameter Corruption(573): 45.38%
# Accuracy loss of Hidden Layer Parameter Corruption(574): 45.67%
# Accuracy loss of Hidden Layer Parameter Corruption(575): 45.77%
# Accuracy loss of Hidden Layer Parameter Corruption(576): 46.28%
# Accuracy loss of Hidden Layer Parameter Corruption(577): 46.25%
# Accuracy loss of Hidden Layer Parameter Corruption(578): 46.19%
# Accuracy loss of Hidden Layer Parameter Corruption(579): 46.28%
# Accuracy loss of Hidden Layer Parameter Corruption(580): 46.34%
# Accuracy loss of Hidden Layer Parameter Corruption(581): 46.50%
# Accuracy loss of Hidden Layer Parameter Corruption(582): 46.67%
# Accuracy loss of Hidden Layer Parameter Corruption(583): 47.01%
# Accuracy loss of Hidden Layer Parameter Corruption(584): 47.19%
# Accuracy loss of Hidden Layer Parameter Corruption(585): 47.18%
# Accuracy loss of Hidden Layer Parameter Corruption(586): 47.31%
# Accuracy loss of Hidden Layer Parameter Corruption(587): 47.44%
# Accuracy loss of Hidden Layer Parameter Corruption(588): 47.62%
# Accuracy loss of Hidden Layer Parameter Corruption(589): 47.88%
# Accuracy loss of Hidden Layer Parameter Corruption(590): 47.98%
# Accuracy loss of Hidden Layer Parameter Corruption(591): 48.03%
# Accuracy loss of Hidden Layer Parameter Corruption(592): 48.10%
# Accuracy loss of Hidden Layer Parameter Corruption(593): 48.24%
# Accuracy loss of Hidden Layer Parameter Corruption(594): 48.43%
# Accuracy loss of Hidden Layer Parameter Corruption(595): 48.51%
# Accuracy loss of Hidden Layer Parameter Corruption(596): 48.84%
# Accuracy loss of Hidden Layer Parameter Corruption(597): 49.31%
# Accuracy loss of Hidden Layer Parameter Corruption(598): 49.66%
# Accuracy loss of Hidden Layer Parameter Corruption(599): 50.24%
# Accuracy loss of Hidden Layer Parameter Corruption(600): 50.40%
# Accuracy loss of Hidden Layer Parameter Corruption(601): 50.53%
# Accuracy loss of Hidden Layer Parameter Corruption(602): 50.90%
# Accuracy loss of Hidden Layer Parameter Corruption(603): 51.11%
# Accuracy loss of Hidden Layer Parameter Corruption(604): 51.43%
# Accuracy loss of Hidden Layer Parameter Corruption(605): 51.79%
# Accuracy loss of Hidden Layer Parameter Corruption(606): 52.13%
# Accuracy loss of Hidden Layer Parameter Corruption(607): 52.21%
# Accuracy loss of Hidden Layer Parameter Corruption(608): 52.41%
# Accuracy loss of Hidden Layer Parameter Corruption(609): 52.76%
# Accuracy loss of Hidden Layer Parameter Corruption(610): 52.86%
# Accuracy loss of Hidden Layer Parameter Corruption(611): 53.01%
# Accuracy loss of Hidden Layer Parameter Corruption(612): 53.19%
# Accuracy loss of Hidden Layer Parameter Corruption(613): 53.18%
# Accuracy loss of Hidden Layer Parameter Corruption(614): 53.47%
# Accuracy loss of Hidden Layer Parameter Corruption(615): 53.74%
# Accuracy loss of Hidden Layer Parameter Corruption(616): 53.87%
# Accuracy loss of Hidden Layer Parameter Corruption(617): 54.13%
# Accuracy loss of Hidden Layer Parameter Corruption(618): 54.40%
# Accuracy loss of Hidden Layer Parameter Corruption(619): 54.43%
# Accuracy loss of Hidden Layer Parameter Corruption(620): 54.53%
# Accuracy loss of Hidden Layer Parameter Corruption(621): 54.78%
# Accuracy loss of Hidden Layer Parameter Corruption(622): 54.86%
# Accuracy loss of Hidden Layer Parameter Corruption(623): 54.91%
# Accuracy loss of Hidden Layer Parameter Corruption(624): 55.17%
# Accuracy loss of Hidden Layer Parameter Corruption(625): 55.33%
# Accuracy loss of Hidden Layer Parameter Corruption(626): 55.44%
# Accuracy loss of Hidden Layer Parameter Corruption(627): 55.60%
# Accuracy loss of Hidden Layer Parameter Corruption(628): 55.72%
# Accuracy loss of Hidden Layer Parameter Corruption(629): 55.78%
# Accuracy loss of Hidden Layer Parameter Corruption(630): 55.93%
# Accuracy loss of Hidden Layer Parameter Corruption(631): 55.99%
# Accuracy loss of Hidden Layer Parameter Corruption(632): 56.15%
# Accuracy loss of Hidden Layer Parameter Corruption(633): 56.30%
# Accuracy loss of Hidden Layer Parameter Corruption(634): 56.26%
# Accuracy loss of Hidden Layer Parameter Corruption(635): 56.24%
# Accuracy loss of Hidden Layer Parameter Corruption(636): 56.39%
# Accuracy loss of Hidden Layer Parameter Corruption(637): 56.75%
# Accuracy loss of Hidden Layer Parameter Corruption(638): 56.79%
# Accuracy loss of Hidden Layer Parameter Corruption(639): 57.11%
# Accuracy loss of Hidden Layer Parameter Corruption(640): 57.20%
# Accuracy loss of Hidden Layer Parameter Corruption(641): 57.30%
# Accuracy loss of Hidden Layer Parameter Corruption(642): 57.72%
# Accuracy loss of Hidden Layer Parameter Corruption(643): 57.84%
# Accuracy loss of Hidden Layer Parameter Corruption(644): 58.15%
# Accuracy loss of Hidden Layer Parameter Corruption(645): 58.27%
# Accuracy loss of Hidden Layer Parameter Corruption(646): 58.47%
# Accuracy loss of Hidden Layer Parameter Corruption(647): 58.65%
# Accuracy loss of Hidden Layer Parameter Corruption(648): 58.66%
# Accuracy loss of Hidden Layer Parameter Corruption(649): 58.89%
# Accuracy loss of Hidden Layer Parameter Corruption(650): 58.96%
# Accuracy loss of Hidden Layer Parameter Corruption(651): 59.08%
# Accuracy loss of Hidden Layer Parameter Corruption(652): 59.20%
# Accuracy loss of Hidden Layer Parameter Corruption(653): 59.46%
# Accuracy loss of Hidden Layer Parameter Corruption(654): 59.66%
# Accuracy loss of Hidden Layer Parameter Corruption(655): 59.81%
# Accuracy loss of Hidden Layer Parameter Corruption(656): 59.86%
# Accuracy loss of Hidden Layer Parameter Corruption(657): 60.05%
# Accuracy loss of Hidden Layer Parameter Corruption(658): 59.91%
# Accuracy loss of Hidden Layer Parameter Corruption(659): 60.01%
# Accuracy loss of Hidden Layer Parameter Corruption(660): 60.14%
# Accuracy loss of Hidden Layer Parameter Corruption(661): 60.21%
# Accuracy loss of Hidden Layer Parameter Corruption(662): 60.37%
# Accuracy loss of Hidden Layer Parameter Corruption(663): 60.57%
# Accuracy loss of Hidden Layer Parameter Corruption(664): 60.72%
# Accuracy loss of Hidden Layer Parameter Corruption(665): 60.81%
# Accuracy loss of Hidden Layer Parameter Corruption(666): 60.75%
# Accuracy loss of Hidden Layer Parameter Corruption(667): 60.97%
# Accuracy loss of Hidden Layer Parameter Corruption(668): 61.06%
# Accuracy loss of Hidden Layer Parameter Corruption(669): 61.23%
# Accuracy loss of Hidden Layer Parameter Corruption(670): 61.40%
# Accuracy loss of Hidden Layer Parameter Corruption(671): 61.50%
# Accuracy loss of Hidden Layer Parameter Corruption(672): 61.62%
# Accuracy loss of Hidden Layer Parameter Corruption(673): 61.84%
# Accuracy loss of Hidden Layer Parameter Corruption(674): 61.93%
# Accuracy loss of Hidden Layer Parameter Corruption(675): 62.24%
# Accuracy loss of Hidden Layer Parameter Corruption(676): 62.33%
# Accuracy loss of Hidden Layer Parameter Corruption(677): 62.36%
# Accuracy loss of Hidden Layer Parameter Corruption(678): 62.45%
# Accuracy loss of Hidden Layer Parameter Corruption(679): 62.63%
# Accuracy loss of Hidden Layer Parameter Corruption(680): 62.66%
# Accuracy loss of Hidden Layer Parameter Corruption(681): 62.72%
# Accuracy loss of Hidden Layer Parameter Corruption(682): 63.01%
# Accuracy loss of Hidden Layer Parameter Corruption(683): 63.13%
# Accuracy loss of Hidden Layer Parameter Corruption(684): 63.25%
# Accuracy loss of Hidden Layer Parameter Corruption(685): 63.44%
# Accuracy loss of Hidden Layer Parameter Corruption(686): 63.52%
# Accuracy loss of Hidden Layer Parameter Corruption(687): 63.70%
# Accuracy loss of Hidden Layer Parameter Corruption(688): 63.99%
# Accuracy loss of Hidden Layer Parameter Corruption(689): 64.05%
# Accuracy loss of Hidden Layer Parameter Corruption(690): 64.26%
# Accuracy loss of Hidden Layer Parameter Corruption(691): 64.33%
# Accuracy loss of Hidden Layer Parameter Corruption(692): 64.50%
# Accuracy loss of Hidden Layer Parameter Corruption(693): 64.71%
# Accuracy loss of Hidden Layer Parameter Corruption(694): 64.85%
# Accuracy loss of Hidden Layer Parameter Corruption(695): 64.89%
# Accuracy loss of Hidden Layer Parameter Corruption(696): 64.94%
# Accuracy loss of Hidden Layer Parameter Corruption(697): 65.00%
# Accuracy loss of Hidden Layer Parameter Corruption(698): 65.07%
# Accuracy loss of Hidden Layer Parameter Corruption(699): 65.05%
# Accuracy loss of Hidden Layer Parameter Corruption(700): 65.20%
# Accuracy loss of Hidden Layer Parameter Corruption(701): 65.27%
# Accuracy loss of Hidden Layer Parameter Corruption(702): 65.43%
# Accuracy loss of Hidden Layer Parameter Corruption(703): 65.49%
# Accuracy loss of Hidden Layer Parameter Corruption(704): 65.58%
# Accuracy loss of Hidden Layer Parameter Corruption(705): 65.70%
# Accuracy loss of Hidden Layer Parameter Corruption(706): 65.94%
# Accuracy loss of Hidden Layer Parameter Corruption(707): 65.88%
# Accuracy loss of Hidden Layer Parameter Corruption(708): 66.05%
# Accuracy loss of Hidden Layer Parameter Corruption(709): 66.26%
# Accuracy loss of Hidden Layer Parameter Corruption(710): 66.48%
# Accuracy loss of Hidden Layer Parameter Corruption(711): 66.54%
# Accuracy loss of Hidden Layer Parameter Corruption(712): 66.76%
# Accuracy loss of Hidden Layer Parameter Corruption(713): 66.78%
# Accuracy loss of Hidden Layer Parameter Corruption(714): 66.82%
# Accuracy loss of Hidden Layer Parameter Corruption(715): 66.94%
# Accuracy loss of Hidden Layer Parameter Corruption(716): 67.01%
# Accuracy loss of Hidden Layer Parameter Corruption(717): 67.04%
# Accuracy loss of Hidden Layer Parameter Corruption(718): 67.08%
# Accuracy loss of Hidden Layer Parameter Corruption(719): 67.46%
# Accuracy loss of Hidden Layer Parameter Corruption(720): 67.56%
# Accuracy loss of Hidden Layer Parameter Corruption(721): 67.57%
# Accuracy loss of Hidden Layer Parameter Corruption(722): 67.65%
# Accuracy loss of Hidden Layer Parameter Corruption(723): 67.71%
# Accuracy loss of Hidden Layer Parameter Corruption(724): 67.68%
# Accuracy loss of Hidden Layer Parameter Corruption(725): 67.74%
# Accuracy loss of Hidden Layer Parameter Corruption(726): 67.76%
# Accuracy loss of Hidden Layer Parameter Corruption(727): 67.94%
# Accuracy loss of Hidden Layer Parameter Corruption(728): 67.89%
# Accuracy loss of Hidden Layer Parameter Corruption(729): 67.88%
# Accuracy loss of Hidden Layer Parameter Corruption(730): 67.90%
# Accuracy loss of Hidden Layer Parameter Corruption(731): 68.19%
# Accuracy loss of Hidden Layer Parameter Corruption(732): 68.20%
# Accuracy loss of Hidden Layer Parameter Corruption(733): 68.26%
# Accuracy loss of Hidden Layer Parameter Corruption(734): 68.27%
# Accuracy loss of Hidden Layer Parameter Corruption(735): 68.41%
# Accuracy loss of Hidden Layer Parameter Corruption(736): 68.57%
# Accuracy loss of Hidden Layer Parameter Corruption(737): 68.53%
# Accuracy loss of Hidden Layer Parameter Corruption(738): 68.66%
# Accuracy loss of Hidden Layer Parameter Corruption(739): 68.73%
# Accuracy loss of Hidden Layer Parameter Corruption(740): 68.80%
# Accuracy loss of Hidden Layer Parameter Corruption(741): 68.86%
# ...
# Accuracy loss of Hidden Layer Parameter Corruption(750): 69.86%
# Accuracy loss of Hidden Layer Parameter Corruption(751): 69.90%
# Accuracy loss of Hidden Layer Parameter Corruption(752): 70.26%
# Accuracy loss of Hidden Layer Parameter Corruption(753): 70.33%
# Accuracy loss of Hidden Layer Parameter Corruption(754): 70.31%
# Accuracy loss of Hidden Layer Parameter Corruption(755): 70.74%
# Accuracy loss of Hidden Layer Parameter Corruption(756): 70.88%
# Accuracy loss of Hidden Layer Parameter Corruption(757): 70.91%
# Accuracy loss of Hidden Layer Parameter Corruption(758): 70.89%
# Accuracy loss of Hidden Layer Parameter Corruption(759): 70.93%
# Accuracy loss of Hidden Layer Parameter Corruption(760): 70.96%
# Accuracy loss of Hidden Layer Parameter Corruption(761): 71.02%
# Accuracy loss of Hidden Layer Parameter Corruption(762): 70.99%
# Accuracy loss of Hidden Layer Parameter Corruption(763): 71.22%
# Accuracy loss of Hidden Layer Parameter Corruption(764): 71.15%
# Accuracy loss of Hidden Layer Parameter Corruption(765): 71.25%
# Accuracy loss of Hidden Layer Parameter Corruption(766): 71.26%
# Accuracy loss of Hidden Layer Parameter Corruption(767): 71.33%
# Accuracy loss of Hidden Layer Parameter Corruption(768): 71.51%
# Accuracy loss of Hidden Layer Parameter Corruption(769): 71.62%
# Accuracy loss of Hidden Layer Parameter Corruption(770): 71.71%
# Accuracy loss of Hidden Layer Parameter Corruption(771): 71.80%
# Accuracy loss of Hidden Layer Parameter Corruption(772): 71.81%
# Accuracy loss of Hidden Layer Parameter Corruption(773): 71.85%
# Accuracy loss of Hidden Layer Parameter Corruption(774): 71.94%
# Accuracy loss of Hidden Layer Parameter Corruption(775): 72.21%
# Accuracy loss of Hidden Layer Parameter Corruption(776): 72.49%
# Accuracy loss of Hidden Layer Parameter Corruption(777): 72.46%
# Accuracy loss of Hidden Layer Parameter Corruption(778): 72.55%
# Accuracy loss of Hidden Layer Parameter Corruption(779): 72.63%
# Accuracy loss of Hidden Layer Parameter Corruption(780): 72.74%
# Accuracy loss of Hidden Layer Parameter Corruption(781): 73.01%
# Accuracy loss of Hidden Layer Parameter Corruption(782): 73.11%
# Accuracy loss of Hidden Layer Parameter Corruption(783): 73.29%
# Accuracy loss of Hidden Layer Parameter Corruption(784): 73.39%
# Accuracy loss of Hidden Layer Parameter Corruption(785): 73.69%
# Accuracy loss of Hidden Layer Parameter Corruption(786): 73.64%
# Accuracy loss of Hidden Layer Parameter Corruption(787): 73.59%
# Accuracy loss of Hidden Layer Parameter Corruption(788): 73.63%
# Accuracy loss of Hidden Layer Parameter Corruption(789): 73.62%
# Accuracy loss of Hidden Layer Parameter Corruption(790): 73.63%
# Accuracy loss of Hidden Layer Parameter Corruption(791): 73.74%
# Accuracy loss of Hidden Layer Parameter Corruption(792): 73.76%
# Accuracy loss of Hidden Layer Parameter Corruption(793): 73.81%
# Accuracy loss of Hidden Layer Parameter Corruption(794): 73.89%
# Accuracy loss of Hidden Layer Parameter Corruption(795): 73.94%
# Accuracy loss of Hidden Layer Parameter Corruption(796): 73.99%
# Accuracy loss of Hidden Layer Parameter Corruption(797): 74.13%
# Accuracy loss of Hidden Layer Parameter Corruption(798): 74.20%
# Accuracy loss of Hidden Layer Parameter Corruption(799): 74.26%
# Accuracy loss of Hidden Layer Parameter Corruption(800): 74.34%
# Accuracy loss of Hidden Layer Parameter Corruption(801): 74.36%
# Accuracy loss of Hidden Layer Parameter Corruption(802): 74.60%
# Accuracy loss of Hidden Layer Parameter Corruption(803): 74.84%
# Accuracy loss of Hidden Layer Parameter Corruption(804): 74.85%
# Accuracy loss of Hidden Layer Parameter Corruption(805): 74.84%
# Accuracy loss of Hidden Layer Parameter Corruption(806): 74.93%
# Accuracy loss of Hidden Layer Parameter Corruption(807): 74.90%
# Accuracy loss of Hidden Layer Parameter Corruption(808): 74.93%
# Accuracy loss of Hidden Layer Parameter Corruption(809): 75.03%
# Accuracy loss of Hidden Layer Parameter Corruption(810): 75.03%
# Accuracy loss of Hidden Layer Parameter Corruption(811): 75.42%
# Accuracy loss of Hidden Layer Parameter Corruption(812): 75.55%
# Accuracy loss of Hidden Layer Parameter Corruption(813): 75.53%
# Accuracy loss of Hidden Layer Parameter Corruption(814): 75.79%
# Accuracy loss of Hidden Layer Parameter Corruption(815): 75.71%
# Accuracy loss of Hidden Layer Parameter Corruption(816): 75.92%
# Accuracy loss of Hidden Layer Parameter Corruption(817): 75.89%
# Accuracy loss of Hidden Layer Parameter Corruption(818): 76.25%
# Accuracy loss of Hidden Layer Parameter Corruption(819): 76.49%
# Accuracy loss of Hidden Layer Parameter Corruption(820): 76.58%
# Accuracy loss of Hidden Layer Parameter Corruption(821): 76.77%
# Accuracy loss of Hidden Layer Parameter Corruption(822): 76.84%
# Accuracy loss of Hidden Layer Parameter Corruption(823): 76.97%
# Accuracy loss of Hidden Layer Parameter Corruption(824): 77.17%
# Accuracy loss of Hidden Layer Parameter Corruption(825): 77.36%
# Accuracy loss of Hidden Layer Parameter Corruption(826): 77.43%
# Accuracy loss of Hidden Layer Parameter Corruption(827): 77.55%
# Accuracy loss of Hidden Layer Parameter Corruption(828): 77.67%
# Accuracy loss of Hidden Layer Parameter Corruption(829): 77.91%
# Accuracy loss of Hidden Layer Parameter Corruption(830): 78.00%
# Accuracy loss of Hidden Layer Parameter Corruption(831): 78.14%
# Accuracy loss of Hidden Layer Parameter Corruption(832): 78.18%
# Accuracy loss of Hidden Layer Parameter Corruption(833): 78.34%
# Accuracy loss of Hidden Layer Parameter Corruption(834): 78.46%
# Accuracy loss of Hidden Layer Parameter Corruption(835): 78.47%
# Accuracy loss of Hidden Layer Parameter Corruption(836): 78.48%
# Accuracy loss of Hidden Layer Parameter Corruption(837): 78.48%
# Accuracy loss of Hidden Layer Parameter Corruption(838): 78.58%
# Accuracy loss of Hidden Layer Parameter Corruption(839): 78.49%
# Accuracy loss of Hidden Layer Parameter Corruption(840): 78.52%
# Accuracy loss of Hidden Layer Parameter Corruption(841): 78.52%
# Accuracy loss of Hidden Layer Parameter Corruption(842): 78.72%
# Accuracy loss of Hidden Layer Parameter Corruption(843): 78.71%
# Accuracy loss of Hidden Layer Parameter Corruption(844): 78.65%
# Accuracy loss of Hidden Layer Parameter Corruption(845): 78.48%
# Accuracy loss of Hidden Layer Parameter Corruption(846): 78.78%
# Accuracy loss of Hidden Layer Parameter Corruption(847): 78.75%
# Accuracy loss of Hidden Layer Parameter Corruption(848): 78.72%
# Accuracy loss of Hidden Layer Parameter Corruption(849): 78.86%
# Accuracy loss of Hidden Layer Parameter Corruption(850): 78.86%
# Accuracy loss of Hidden Layer Parameter Corruption(851): 78.90%
# Accuracy loss of Hidden Layer Parameter Corruption(852): 78.90%
# Accuracy loss of Hidden Layer Parameter Corruption(853): 78.91%
# Accuracy loss of Hidden Layer Parameter Corruption(854): 78.87%
# Accuracy loss of Hidden Layer Parameter Corruption(855): 79.06%
# Accuracy loss of Hidden Layer Parameter Corruption(856): 79.14%
# Accuracy loss of Hidden Layer Parameter Corruption(857): 79.08%
# Accuracy loss of Hidden Layer Parameter Corruption(858): 79.20%
# Accuracy loss of Hidden Layer Parameter Corruption(859): 79.17%
# Accuracy loss of Hidden Layer Parameter Corruption(860): 79.34%
# Accuracy loss of Hidden Layer Parameter Corruption(861): 79.45%
# Accuracy loss of Hidden Layer Parameter Corruption(862): 79.45%
# Accuracy loss of Hidden Layer Parameter Corruption(863): 79.61%
# Accuracy loss of Hidden Layer Parameter Corruption(864): 79.70%
# Accuracy loss of Hidden Layer Parameter Corruption(865): 79.76%
# Accuracy loss of Hidden Layer Parameter Corruption(866): 79.82%
# Accuracy loss of Hidden Layer Parameter Corruption(867): 79.96%
# Accuracy loss of Hidden Layer Parameter Corruption(868): 80.10%
# Accuracy loss of Hidden Layer Parameter Corruption(869): 80.11%
# Accuracy loss of Hidden Layer Parameter Corruption(870): 80.17%
# Accuracy loss of Hidden Layer Parameter Corruption(871): 80.21%
# Accuracy loss of Hidden Layer Parameter Corruption(872): 80.32%
# Accuracy loss of Hidden Layer Parameter Corruption(873): 80.37%
# Accuracy loss of Hidden Layer Parameter Corruption(874): 80.47%
# Accuracy loss of Hidden Layer Parameter Corruption(875): 80.63%
# Accuracy loss of Hidden Layer Parameter Corruption(876): 80.62%
# Accuracy loss of Hidden Layer Parameter Corruption(877): 80.60%
# Accuracy loss of Hidden Layer Parameter Corruption(878): 80.62%
# Accuracy loss of Hidden Layer Parameter Corruption(879): 80.69%
# Accuracy loss of Hidden Layer Parameter Corruption(880): 80.68%
# Accuracy loss of Hidden Layer Parameter Corruption(881): 80.71%
# Accuracy loss of Hidden Layer Parameter Corruption(882): 80.74%
# Accuracy loss of Hidden Layer Parameter Corruption(883): 80.81%
# Accuracy loss of Hidden Layer Parameter Corruption(884): 80.87%
# Accuracy loss of Hidden Layer Parameter Corruption(885): 80.91%
# Accuracy loss of Hidden Layer Parameter Corruption(886): 80.91%
# Accuracy loss of Hidden Layer Parameter Corruption(887): 80.87%
# Accuracy loss of Hidden Layer Parameter Corruption(888): 80.87%
# Accuracy loss of Hidden Layer Parameter Corruption(889): 80.87%
# Accuracy loss of Hidden Layer Parameter Corruption(890): 80.96%
# Accuracy loss of Hidden Layer Parameter Corruption(891): 81.02%
# Accuracy loss of Hidden Layer Parameter Corruption(892): 81.03%
# Accuracy loss of Hidden Layer Parameter Corruption(893): 81.08%
# Accuracy loss of Hidden Layer Parameter Corruption(894): 81.14%
# Accuracy loss of Hidden Layer Parameter Corruption(895): 81.15%
# Accuracy loss of Hidden Layer Parameter Corruption(896): 81.14%
# Accuracy loss of Hidden Layer Parameter Corruption(897): 81.19%
# Accuracy loss of Hidden Layer Parameter Corruption(898): 81.20%
# Accuracy loss of Hidden Layer Parameter Corruption(899): 81.20%
# Accuracy loss of Hidden Layer Parameter Corruption(900): 81.22%
# Accuracy loss of Hidden Layer Parameter Corruption(901): 81.24%
# Accuracy loss of Hidden Layer Parameter Corruption(902): 81.32%
# Accuracy loss of Hidden Layer Parameter Corruption(903): 81.32%
# Accuracy loss of Hidden Layer Parameter Corruption(904): 81.31%
# Accuracy loss of Hidden Layer Parameter Corruption(905): 81.33%
# Accuracy loss of Hidden Layer Parameter Corruption(906): 81.33%
# Accuracy loss of Hidden Layer Parameter Corruption(907): 81.35%
# Accuracy loss of Hidden Layer Parameter Corruption(908): 81.35%
# Accuracy loss of Hidden Layer Parameter Corruption(909): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(910): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(911): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(912): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(913): 81.36%
# Accuracy loss of Hidden Layer Parameter Corruption(914): 81.36%
# Accuracy loss of Hidden Layer Parameter Corruption(915): 81.36%
# Accuracy loss of Hidden Layer Parameter Corruption(916): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(917): 81.37%
# Accuracy loss of Hidden Layer Parameter Corruption(918): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(919): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(920): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(921): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(922): 81.39%
# Accuracy loss of Hidden Layer Parameter Corruption(923): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(924): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(925): 81.39%
# Accuracy loss of Hidden Layer Parameter Corruption(926): 81.38%
# Accuracy loss of Hidden Layer Parameter Corruption(927): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(928): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(929): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(930): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(931): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(932): 81.40%
# Accuracy loss of Hidden Layer Parameter Corruption(933): 81.42%
# Accuracy loss of Hidden Layer Parameter Corruption(934): 81.42%
# Accuracy loss of Hidden Layer Parameter Corruption(935): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(936): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(937): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(938): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(939): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(940): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(941): 81.43%
# Accuracy loss of Hidden Layer Parameter Corruption(942): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(943): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(944): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(945): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(946): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(947): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(948): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(949): 81.44%
# Accuracy loss of Hidden Layer Parameter Corruption(950): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(951): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(952): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(953): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(954): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(955): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(956): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(957): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(958): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(959): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(960): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(961): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(962): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(963): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(964): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(965): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(966): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(967): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(968): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(969): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(970): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(971): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(972): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(973): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(974): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(975): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(976): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(977): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(978): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(979): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(980): 81.45%
# Accuracy loss of Hidden Layer Parameter Corruption(981): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(982): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(983): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(984): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(985): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(986): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(987): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(988): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(989): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(990): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(991): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(992): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(993): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(994): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(995): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(996): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(997): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(998): 81.46%
# Accuracy loss of Hidden Layer Parameter Corruption(999): 81.46%
